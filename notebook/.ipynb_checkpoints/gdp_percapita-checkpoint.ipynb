# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df= pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2021  1517.016266              NaN
# 1     Afghanistan  2020  1968.341002              NaN
# 2     Afghanistan  2019  2079.921861              NaN
# 3     Afghanistan  2018  2060.698973              NaN
# 4     Afghanistan  2017  2096.093111              NaN

# %% [markdown]
# 5. How many rows and columns are in `gdp_df`? What are the data types of each column?

# %%
gdp_df.shape
# Out:
# (7662, 4)

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# 6.Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area': 'Country', 'Year': 'Year','Value' :'GDP_Per_Capita'})
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2021     1517.016266
# 1  Afghanistan  2020     1968.341002
# 2  Afghanistan  2019     2079.921861
# 3  Afghanistan  2018     2060.698973
# 4  Afghanistan  2017     2096.093111

# %% [markdown]
# 7. How many countries have data for all years? Which countries are missing many years of data? Look at the number of observations per year. What do you notice?

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         7662 non-null   object
#  1   Year            7662 non-null   int64
#  2   GDP_Per_Capita  7662 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 179.7+ KB

# %%
num_countries = gdp_df['Country'].value_counts()
num_countries
# Out:
# Country
# Least developed countries: UN classification    33
# Middle East & North Africa                      33
# Middle East & North Africa (IDA & IBRD)         33
# Middle income                                   33
# Mongolia                                        33
#                                                 ..
# Kosovo                                          15
# Sint Maarten (Dutch part)                       14
# Turks and Caicos Islands                        12
# Somalia                                         10
# Djibouti                                        10
# Name: count, Length: 242, dtype: int64

# %%
gdp_df.nunique()
# Out:
# Country            242
# Year                33
# GDP_Per_Capita    7624
# dtype: int64

# %%
observations_per_year = gdp_df.Year.value_counts()
observations_per_year
# Out:
# Year
# 2013    242
# 2016    242
# 2014    242
# 2015    242
# 2020    242
# 2017    242
# 2018    242
# 2019    242
# 2021    241
# 2012    240
# 2011    240
# 2010    239
# 2009    239
# 2008    238
# 2007    237
# 2006    237
# 2004    236
# 2005    236
# 2003    235
# 2002    235
# 2001    234
# 2000    233
# 2022    232
# 1999    227
# 1998    226
# 1997    226
# 1996    223
# 1995    223
# 1994    213
# 1993    211
# 1992    210
# 1991    208
# 1990    207
# Name: count, dtype: int64

# %% [markdown]
# 8. In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?

# %%
gdp_per_capita_2020 = gdp_df.loc[gdp_df['Year']==2020]
gdp_per_capita_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %% [markdown]
# gdp_per_capita_2020['GDP_Per_Capita'].hist(bins = 10,
#                             color = '#99FFFF',
#                             edgecolor = 'black',
#                             figsize = (10,6),
#                             grid = False)
#
#
# plt.title('Distribution of GDP per capita for the year 2020', fontsize = 16);

# %%
gdp_per_capita_2020['GDP_Per_Capita'].hist();

# %% [markdown]
# Density plot

# %%
sns.kdeplot(gdp_per_capita_2020['GDP_Per_Capita']);
# Out:
# C:\Users\TitanUp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Boxplot

# %%
sns.set_theme(style="darkgrid")
sns.boxplot(y=gdp_per_capita_2020["GDP_Per_Capita"])
plt.show()

# %% [markdown]
# Violin plot

# %%
# plot
sns.violinplot(x=gdp_per_capita_2020["Year"], y=gdp_per_capita_2020["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# 9. What was the median GDP per capita value in 2020?

# %% [markdown]
# Max in Year	2022  and GDP_Per_Capita is	157602.482546

# %% [markdown]
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
# 	* A boxplot
# 	* A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
# 	* A scatterplot
# 	* A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.

# %%
my_list = [1990,2000,2010,2020]
gdp_decades = gdp_df.loc[gdp_df.Year.isin(my_list)]
gdp_decades.shape
# Out:
# (921, 3)

# %%
gdp_decades
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 11                    Afghanistan  2010     2026.163818
# 22    Africa Eastern and Southern  2020     3455.023119
# 32    Africa Eastern and Southern  2010     3513.315920
# 42    Africa Eastern and Southern  2000     2897.140841
# ...                           ...   ...             ...
# 7628                       Zambia  1990     2290.039226
# 7631                     Zimbabwe  2020     1990.319419
# 7641                     Zimbabwe  2010     1799.540233
# 7651                     Zimbabwe  2000     2750.601236
# 7661                     Zimbabwe  1990     2704.757299
#
# [921 rows x 3 columns]

# %%
sns.boxplot(data = gdp_decades, y = 'GDP_Per_Capita', x='Year');

# %%
sns.barplot(data = gdp_decades, y = 'GDP_Per_Capita', x='Year');

# %%
sns.scatterplot(data = gdp_decades, y = 'GDP_Per_Capita', x='Year');

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(
    x=gdp_decades["Year"],
    y=gdp_decades["GDP_Per_Capita"],
    line_kws={"color": "r"},
    ax=ax
)
plt.show()

# %% [markdown]
#  what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot

# %% [markdown]
# The GDP values over years and from 1990 to 2020 Gdp values are increasing by decade 2020 has Max GDP value,1990 has Min GDP value.

# %% [markdown]
# 11. Which country was the first to have a GDP per capita greater than $100,000?

# %%
countries_gdp = gdp_df.loc[gdp_df['GDP_Per_Capita']>= 100000]
countries_gdp
# Out:
#                    Country  Year  GDP_Per_Capita
# 3277               Ireland  2022   113870.785550
# 3278               Ireland  2021   102785.490239
# 4146            Luxembourg  2022   115541.774828
# 4147            Luxembourg  2021   115683.493708
# 4148            Luxembourg  2020   111751.314751
# 4149            Luxembourg  2019   114542.496934
# 4150            Luxembourg  2018   114164.468558
# 4151            Luxembourg  2017   114985.842236
# 4152            Luxembourg  2016   116283.699681
# 4153            Luxembourg  2015   113182.728563
# 4154            Luxembourg  2014   113313.578898
# 4155            Luxembourg  2013   113050.663254
# 4156            Luxembourg  2012   112137.135491
# 4157            Luxembourg  2011   112998.390477
# 4158            Luxembourg  2010   114343.988089
# 4159            Luxembourg  2009   112230.081410
# 4160            Luxembourg  2008   118154.667184
# 4161            Luxembourg  2007   120647.822959
# ...

# %% [markdown]
# 12.Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset

# %%
gdp_df.max()
# Out:
# Country                Zimbabwe
# Year                       2022
# GDP_Per_Capita    157602.482546
# dtype: object

# %%
gdp_df.describe()
# Out:
#               Year  GDP_Per_Capita
# count  7662.000000     7662.000000
# mean   2006.388280    17206.979219
# std       9.418727    19363.258695
# min    1990.000000      436.376416
# 25%    1998.000000     3655.268993
# 50%    2007.000000    10132.449293
# 75%    2015.000000    24119.515045
# max    2022.000000   157602.482546

# %%
countries_high_gdp_2020 = gdp_df.loc[gdp_df['Year']==2020]
countries_high_gdp_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %%
countries_high_gdp_2020.sort_values('GDP_Per_Capita',ascending=False)
# Out:
#                        Country  Year  GDP_Per_Capita
# 4148                Luxembourg  2020   111751.314751
# 6108                 Singapore  2020    94910.101431
# 3279                   Ireland  2020    91356.855054
# 5746                     Qatar  2020    89019.069857
# 681                    Bermuda  2020    76117.804744
# ...                        ...   ...             ...
# 5074                     Niger  2020     1214.546556
# 6273                   Somalia  2020     1127.418534
# 1630           Dem. Rep. Congo  2020     1044.071214
# 1217  Central African Republic  2020      847.765012
# 973                    Burundi  2020      711.355263
#
# [242 rows x 3 columns]

# %%
sns.boxplot(data = countries_high_gdp_2020, y = 'GDP_Per_Capita', x='Year');

# %%
countries_high_gdp_2020['GDP_Per_Capita'].hist(bins = 25, color = 'coral', edgecolor = 'black', figsize = (10,6))

plt.title('country GDP per capita', fontsize = 16);

# %% [markdown]
# 13. Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
countries_low_gdp_2020 = gdp_df.loc[gdp_df['Year']==2020]
countries_low_gdp_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %%
countries_low_gdp_2020.sort_values('GDP_Per_Capita',ascending=True)
# Out:
#                        Country  Year  GDP_Per_Capita
# 973                    Burundi  2020      711.355263
# 1217  Central African Republic  2020      847.765012
# 1630           Dem. Rep. Congo  2020     1044.071214
# 6273                   Somalia  2020     1127.418534
# 5074                     Niger  2020     1214.546556
# ...                        ...   ...             ...
# 681                    Bermuda  2020    76117.804744
# 5746                     Qatar  2020    89019.069857
# 3279                   Ireland  2020    91356.855054
# 6108                 Singapore  2020    94910.101431
# 4148                Luxembourg  2020   111751.314751
#
# [242 rows x 3 columns]

# %%
countries_low_gdp_2020['GDP_Per_Capita'].hist(bins = 25, color = 'coral', edgecolor = 'black', figsize = (10,6))

plt.title('country GDP per capita', fontsize = 16);

# %% [markdown]
# Bonus question: Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?

# %%
gdp_1990 = gdp_df.loc[gdp_df['Year']==1990] 
gdp_1990
# Out:
#                           Country  Year  GDP_Per_Capita
# 52    Africa Eastern and Southern  1990     3037.297466
# 85     Africa Western and Central  1990     2788.301039
# 118                       Albania  1990     4827.027705
# 151                       Algeria  1990     8828.874473
# 184                        Angola  1990     5793.084512
# ...                           ...   ...             ...
# 7500                      Vanuatu  1990     2774.138350
# 7533                     Viet Nam  1990     2099.394649
# 7595                        World  1990     9705.981267
# 7628                       Zambia  1990     2290.039226
# 7661                     Zimbabwe  1990     2704.757299
#
# [207 rows x 3 columns]

# %%
gdp_2020 = gdp_df.loc[gdp_df['Year']==2020] 
gdp_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %%
gdp_1990 = pd.DataFrame(gdp_1990)
gdp_2020 = pd.DataFrame(gdp_2020)

# %%
gdp_1990.head(1)
# Out:
#                         Country  Year  GDP_Per_Capita
# 52  Africa Eastern and Southern  1990     3037.297466

# %%
gdp_2020.head(1)
# Out:
#        Country  Year  GDP_Per_Capita
# 1  Afghanistan  2020     1968.341002

# %%
concat_data = pd.concat([gdp_1990, gdp_2020 ]) 
concat_data
# Out:
#                           Country  Year  GDP_Per_Capita
# 52    Africa Eastern and Southern  1990     3037.297466
# 85     Africa Western and Central  1990     2788.301039
# 118                       Albania  1990     4827.027705
# 151                       Algeria  1990     8828.874473
# 184                        Angola  1990     5793.084512
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [449 rows x 3 columns]

# %%
sns.barplot(data = concat_data, y = 'GDP_Per_Capita', x='Year');

# %% [markdown]
# 14. Read in the internet use dataset into a DataFrame named `internet_df`. You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.

# %%
internet_use= pd.read_csv('../data/internet_use.csv',nrows=6083)

# %%
internet_use
# Out:
#      Country or Area  Year      Value Value Footnotes
# 0        Afghanistan  2019  17.600000               1
# 1        Afghanistan  2018  16.800000               2
# 2        Afghanistan  2017  13.500000               3
# 3        Afghanistan  2016  11.000000               4
# 4        Afghanistan  2015   8.260000               4
# ...              ...   ...        ...             ...
# 6078        Zimbabwe  1997   0.033080             NaN
# 6079        Zimbabwe  1996   0.016790             NaN
# 6080        Zimbabwe  1995   0.007684             NaN
# 6081        Zimbabwe  1994   0.001739             NaN
# 6082        Zimbabwe  1990   0.000000             NaN
#
# [6083 rows x 4 columns]

# %% [markdown]
# 15. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.

# %%
internet_use = internet_use.drop(columns = ['Value Footnotes'])

# %%
internet_use = internet_use.rename(columns = {'Country or Area': 'Country', 'Year': 'Year','Value' :'Internet_Users_Pct'})
internet_use.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2019               17.60
# 1  Afghanistan  2018               16.80
# 2  Afghanistan  2017               13.50
# 3  Afghanistan  2016               11.00
# 4  Afghanistan  2015                8.26

# %% [markdown]
# 16. Look at the number of observations in this dataset per year. What do you notice?

# %%
observations = internet_use.value_counts()
observations
# Out:
# Country      Year  Internet_Users_Pct
# Afghanistan  1990  0.0000                1
# Nicaragua    2009  7.3000                1
#              2018  37.6000               1
#              2017  30.4000               1
#              2016  24.5718               1
#                                         ..
# France       2013  81.9198               1
#              2012  81.4400               1
#              2011  77.8200               1
#              2010  77.2800               1
# Zimbabwe     2022  32.5615               1
# Name: count, Length: 6083, dtype: int64

# %% [markdown]
# 17. What is the first year to have a non-zero internet users percentage value?

# %%
ANSWER:1990

# %%
internet_non_zero=internet_use.loc[internet_use['Internet_Users_Pct']!=0]
internet_non_zero
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2019           17.600000
# 1     Afghanistan  2018           16.800000
# 2     Afghanistan  2017           13.500000
# 3     Afghanistan  2016           11.000000
# 4     Afghanistan  2015            8.260000
# ...           ...   ...                 ...
# 6077     Zimbabwe  1998            0.081648
# 6078     Zimbabwe  1997            0.033080
# 6079     Zimbabwe  1996            0.016790
# 6080     Zimbabwe  1995            0.007684
# 6081     Zimbabwe  1994            0.001739
#
# [5803 rows x 3 columns]

# %%
internet_non_zero= internet_use.value_counts(normalize=True)
internet_non_zero.head()
# Out:
# Country      Year  Internet_Users_Pct
# Afghanistan  1990  0.0000                0.000164
# Nicaragua    2009  7.3000                0.000164
#              2018  37.6000               0.000164
#              2017  30.4000               0.000164
#              2016  24.5718               0.000164
# Name: proportion, dtype: float64

# %% [markdown]
# 18. How does the distribution of internet users percent differ for 2000 and 2014?

# %%
my_list = [2000, 2014]
internet_users_percent = internet_use.loc[internet_use.Year.isin(my_list)]
internet_users_percent.shape
# Out:
# (414, 3)

# %%
internet_users_percent
# Out:
#           Country  Year  Internet_Users_Pct
# 5     Afghanistan  2014            7.000000
# 28        Albania  2014           54.300000
# 42        Albania  2000            0.114097
# 57        Algeria  2014           29.500000
# 71        Algeria  2000            0.491706
# ...           ...   ...                 ...
# 6017        Yemen  2000            0.082500
# 6031       Zambia  2014            6.500000
# 6045       Zambia  2000            0.191072
# 6061     Zimbabwe  2014           16.364700
# 6075     Zimbabwe  2000            0.401434
#
# [414 rows x 3 columns]

# %%
sns.boxplot(data = internet_users_percent, y = 'Internet_Users_Pct', x='Year');

# %% [markdown]
# 19. For how many countries was the percentage of internet users below 5% in 2014?

# %%
user_percentage = internet_use.loc[internet_use['Year'] == 2014]
user_percentage
# Out:
#                   Country  Year  Internet_Users_Pct
# 5             Afghanistan  2014              7.0000
# 28                Albania  2014             54.3000
# 57                Algeria  2014             29.5000
# 87                Andorra  2014             86.1000
# 114                Angola  2014             21.3623
# ...                   ...   ...                 ...
# 5937             Viet Nam  2014             41.0000
# 5960  Virgin Islands (US)  2014             50.0700
# 6003                Yemen  2014             22.5500
# 6031               Zambia  2014              6.5000
# 6061             Zimbabwe  2014             16.3647
#
# [204 rows x 3 columns]

# %%
countries_5_low = user_percentage.loc[user_percentage['Internet_Users_Pct'] < 5]
countries_5_low
# Out:
#                                Country  Year  Internet_Users_Pct
# 873                            Burundi  2014             1.04239
# 1033          Central African Republic  2014             2.70000
# 1061                              Chad  2014             2.90000
# 1517  Democratic Republic of the Congo  2014             3.00000
# 1782                           Eritrea  2014             0.99000
# 2451                     Guinea-Bissau  2014             3.32000
# 3364                        Madagascar  2014             3.70000
# 4073                             Niger  2014             1.24868
# 5055                           Somalia  2014             1.63000
# 5116                       South Sudan  2014             2.60000

# %% [markdown]
# 20.Merge the two DataFrames to one. Do this in a way that keeps **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`. Look at the first and last few rows to confirm that it merged correctly.

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2021     1517.016266
# 1     Afghanistan  2020     1968.341002
# 2     Afghanistan  2019     2079.921861
# 3     Afghanistan  2018     2060.698973
# 4     Afghanistan  2017     2096.093111
# ...           ...   ...             ...
# 7657     Zimbabwe  1994     2670.106615
# 7658     Zimbabwe  1993     2458.783255
# 7659     Zimbabwe  1992     2468.278257
# 7660     Zimbabwe  1991     2781.787843
# 7661     Zimbabwe  1990     2704.757299
#
# [7662 rows x 3 columns]

# %%
internet_use
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2019           17.600000
# 1     Afghanistan  2018           16.800000
# 2     Afghanistan  2017           13.500000
# 3     Afghanistan  2016           11.000000
# 4     Afghanistan  2015            8.260000
# ...           ...   ...                 ...
# 6078     Zimbabwe  1997            0.033080
# 6079     Zimbabwe  1996            0.016790
# 6080     Zimbabwe  1995            0.007684
# 6081     Zimbabwe  1994            0.001739
# 6082     Zimbabwe  1990            0.000000
#
# [6083 rows x 3 columns]

# %%
gdp_and_internet_use = pd.merge(gdp_df,internet_use,
                                left_on = ['Year','Country'], right_on = ['Year','Country'],
                                how = 'inner')
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2019     2079.921861               17.60
# 1  Afghanistan  2018     2060.698973               16.80
# 2  Afghanistan  2017     2096.093111               13.50
# 3  Afghanistan  2016     2101.422187               11.00
# 4  Afghanistan  2015     2108.714173                8.26

# %%
gdp_and_internet_use.tail()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4628  Zimbabwe  1997     2896.147308            0.033080
# 4629  Zimbabwe  1996     2867.026043            0.016790
# 4630  Zimbabwe  1995     2641.378271            0.007684
# 4631  Zimbabwe  1994     2670.106615            0.001739
# 4632  Zimbabwe  1990     2704.757299            0.000000

# %% [markdown]
# 21. Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html)

# %%
users_2014 = internet_use.loc[internet_use['Year'] == 2014]
users_2014
# Out:
#                   Country  Year  Internet_Users_Pct
# 5             Afghanistan  2014              7.0000
# 28                Albania  2014             54.3000
# 57                Algeria  2014             29.5000
# 87                Andorra  2014             86.1000
# 114                Angola  2014             21.3623
# ...                   ...   ...                 ...
# 5937             Viet Nam  2014             41.0000
# 5960  Virgin Islands (US)  2014             50.0700
# 6003                Yemen  2014             22.5500
# 6031               Zambia  2014              6.5000
# 6061             Zimbabwe  2014             16.3647
#
# [204 rows x 3 columns]

# %%
highest_internet_users_percentage = users_2014.sort_values('Internet_Users_Pct',ascending=False ) 
highest_internet_users_percentage
# Out:
#                           Country  Year  Internet_Users_Pct
# 2592                      Iceland  2014            98.15800
# 1893  Falkland (Malvinas) Islands  2014            97.60000
# 602                       Bermuda  2014            96.80000
# 4173                       Norway  2014            96.30050
# 1546                      Denmark  2014            95.99350
# ...                           ...   ...                 ...
# 5116                  South Sudan  2014             2.60000
# 5055                      Somalia  2014             1.63000
# 4073                        Niger  2014             1.24868
# 873                       Burundi  2014             1.04239
# 1782                      Eritrea  2014             0.99000
#
# [204 rows x 3 columns]

# %%
my_list = ["Iceland", "Falkland (Malvinas) Islands", "Bermuda"  ]
top_three_countries = highest_internet_users_percentage.loc[internet_use.Country.isin(my_list)]
top_three_countries
# Out:
#                           Country  Year  Internet_Users_Pct
# 2592                      Iceland  2014              98.158
# 1893  Falkland (Malvinas) Islands  2014              97.600
# 602                       Bermuda  2014              96.800

# %%
g = sns.FacetGrid(top_three_countries, col="Year", height=3.5, aspect=.65 )
g.map(sns.histplot, "Internet_Users_Pct");
# Out:
# C:\Users\TitanUp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
g = sns.FacetGrid(top_three_countries, col="Year", row="Internet_Users_Pct", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="Internet_Users_Pct", y="Year")
g.set_axis_labels("Internet_Users_Pct")
g.set_titles(col_template="{col_name} top_three", row_template="{row_name}")
g.set(xlim=(0, 60), ylim=(0, 12), xticks=[10, 30, 50], yticks=[2, 6, 10])
g.tight_layout()
g.savefig("facet_plot.png")

# %% [markdown]
# 22. Subset `gdp_and_internet_use` to just the year 2014. Save this as a new dataframe named `gdp_and_internet_use_2014`.

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use.loc[gdp_and_internet_use['Year'] == 2014] 
gdp_and_internet_use_2014
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5             Afghanistan  2014     2144.449634              7.0000
# 26                Albania  2014    11586.817446             54.3000
# 55                Algeria  2014    11561.259795             29.5000
# 85                 Angola  2014     8183.164577             21.3623
# 113   Antigua and Barbuda  2014    18779.139077             67.7800
# ...                   ...   ...             ...                 ...
# 4496           Uzbekistan  2014     6075.192224             35.5000
# 4525              Vanuatu  2014     2917.677875             18.8000
# 4553             Viet Nam  2014     7641.909252             41.0000
# 4581               Zambia  2014     3375.941270              6.5000
# 4611             Zimbabwe  2014     2316.954536             16.3647
#
# [162 rows x 4 columns]

# %% [markdown]
# 23. Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.

# %%
plt.scatter(gdp_and_internet_use_2014.Internet_Users_Pct, gdp_and_internet_use_2014.GDP_Per_Capita)
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita')
plt.show()

# %%
plt.scatter(gdp_and_internet_use_2014.Internet_Users_Pct, gdp_and_internet_use_2014.GDP_Per_Capita, color = 'green', marker ='s')
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita')
plt.show()

# %% [markdown]
# **Stretch Question:** Use the `qcut` function from pandas (https://pandas.pydata.org/docs/reference/api/pandas.qcut.html) to divide countries in `gdp_per_capita_2014` into three groups based on their GDP per capita values. Label these groups as "Low", "Medium", and "High". Put these labels in a new column, named "GDP_group".

# %%
gdp_and_internet_use_2014['GDP_group'] = pd.qcut(gdp_and_internet_use_2014['GDP_Per_Capita'],3,['Low' ,'Medium', 'High'])
# Out:
# C:\Users\TitanUp\AppData\Local\Temp\ipykernel_27780\597975564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_and_internet_use_2014['GDP_group'] = pd.qcut(gdp_and_internet_use_2014['GDP_Per_Capita'],3,['Low' ,'Medium', 'High'])

# %%
gdp_and_internet_use_2014
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct GDP_group
# 5             Afghanistan  2014     2144.449634              7.0000       Low
# 26                Albania  2014    11586.817446             54.3000    Medium
# 55                Algeria  2014    11561.259795             29.5000    Medium
# 85                 Angola  2014     8183.164577             21.3623    Medium
# 113   Antigua and Barbuda  2014    18779.139077             67.7800    Medium
# ...                   ...   ...             ...                 ...       ...
# 4496           Uzbekistan  2014     6075.192224             35.5000       Low
# 4525              Vanuatu  2014     2917.677875             18.8000       Low
# 4553             Viet Nam  2014     7641.909252             41.0000    Medium
# 4581               Zambia  2014     3375.941270              6.5000       Low
# 4611             Zimbabwe  2014     2316.954536             16.3647       Low
#
# [162 rows x 5 columns]

# %% [markdown]
# 25. **Stretch Question:** How does the median internet users percentage compare for the three gdp groups?

# %%
plt.scatter(gdp_and_internet_use_2014.Internet_Users_Pct, gdp_and_internet_use_2014.GDP_group, color = 'green', marker ='s')
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_group')
plt.show()
